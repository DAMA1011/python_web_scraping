# %%
'''
匯入工具

備註: 每次執行以下任一範例前，都要執行一次"匯入工具"的 cell
'''

# 操作 browser 的 API
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 加入行為鍊 ActionChain (在 WebDriver 中模擬滑鼠移動、點繫、拖曳、按右鍵出現選單，以及鍵盤輸入文字、按下鍵盤上的按鈕等)
from selenium.webdriver.common.action_chains import ActionChains

# 加入鍵盤功能 (例如 Ctrl、Alt 等)
from selenium.webdriver.common.keys import Keys

# 強制等待 (執行期間休息一下)
from time import sleep

import pyautogui

import keyboard

# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消通知

# 使用 Chrome 的 WebDriver
driver = webdriver.Chrome(
    options = my_options,
    service = Service(ChromeDriverManager().install())
)

# %%
def visit():
    # 前往頁面
    driver.get('https://www.musicca.com/drums')
    
    sleep(2)

def click():
    # 建立行為鍊
    ac = ActionChains(driver)

    ac.key_down(Keys.CONTROL).send_keys('yx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
 

    for i in range(2):
        ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
        ac.pause(0.3)
        
        ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
        ac.pause(0.3)

        
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)

    
    ac.key_down(Keys.CONTROL).send_keys('yx').key_up(Keys.CONTROL)
    ac.pause(0.3)

    
    ac.pause(2)
 

    ac.key_down(Keys.CONTROL).send_keys('yx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)

    
    for i in range(2):
        ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
        ac.pause(0.3)
        
        ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
        ac.pause(0.3)
        ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
        ac.pause(0.3)
  

    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.15)
    ac.key_down(Keys.CONTROL).send_keys('s').key_up(Keys.CONTROL)
    ac.pause(0.15)
    
    
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('h').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    
    ac.key_down(Keys.CONTROL).send_keys('yx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    
    ac.pause(2)
    
    
    ac.key_down(Keys.CONTROL).send_keys('yx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)

    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('e').key_up(Keys.CONTROL)
    ac.pause(0.3)

    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
        
        
    ac.key_down(Keys.CONTROL).send_keys('rx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('sr').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.15)
    ac.key_down(Keys.CONTROL).send_keys('s').key_up(Keys.CONTROL)
    ac.pause(0.15)
    
    ac.key_down(Keys.CONTROL).send_keys('r').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('s').key_up(Keys.CONTROL)
    ac.pause(0.15)
    ac.key_down(Keys.CONTROL).send_keys('s').key_up(Keys.CONTROL)
    ac.pause(0.15)
    ac.key_down(Keys.CONTROL).send_keys('g').key_up(Keys.CONTROL)
    ac.pause(0.3)
    ac.key_down(Keys.CONTROL).send_keys('h').key_up(Keys.CONTROL)
    ac.pause(0.15)
    ac.key_down(Keys.CONTROL).send_keys('h').key_up(Keys.CONTROL)
    ac.pause(0.15)
    
    ac.key_down(Keys.CONTROL).send_keys('yx').key_up(Keys.CONTROL)
    ac.pause(0.3)
    
    # 執行
    ac.perform()



if __name__ == '__main__':
    visit()
    click()

# %%
driver.get('https://www.musicca.com/guitar')
    
sleep(1)

ele = driver.find_elements(By.CSS_SELECTOR, "i.note-name")


ac = ActionChains(driver)

# 1
ac.move_to_element(ele[14]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)

# 2
ac.move_to_element(ele[7]).click()
ac.pause(0.3)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)

# 3
ac.move_to_element(ele[1]).click()
ac.pause(0.6)
ac.move_to_element(ele[15]).click()
ac.pause(0.2)

# 4
ac.move_to_element(ele[14]).click()
ac.pause(0.3)
ac.move_to_element(ele[2]).click()
ac.pause(0.1)
ac.move_to_element(ele[14]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 5
ac.move_to_element(ele[2]).click()
ac.pause(0.6)
ac.move_to_element(ele[15]).click()
ac.pause(0.2)

# 6
ac.move_to_element(ele[21]).click()
ac.pause(0.3)
ac.move_to_element(ele[15]).click()
ac.pause(0.1)
ac.move_to_element(ele[21]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 7
ac.move_to_element(ele[15]).click()
ac.pause(0.6)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)

# 8
ac.move_to_element(ele[1]).click()
ac.pause(0.3)
ac.move_to_element(ele[27]).click()
ac.pause(0.1)
ac.move_to_element(ele[27]).click()
ac.pause(0.2)
ac.move_to_element(ele[1]).click()
ac.pause(0.2)

# 9
ac.move_to_element(ele[1]).click()
ac.pause(0.6)
ac.move_to_element(ele[14]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)

# 10
ac.move_to_element(ele[7]).click()
ac.pause(0.3)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)

# 11
ac.move_to_element(ele[1]).click()
ac.pause(0.6)
ac.move_to_element(ele[15]).click()
ac.pause(0.2)

# 12
ac.move_to_element(ele[14]).click()
ac.pause(0.3)
ac.move_to_element(ele[2]).click()
ac.pause(0.1)
ac.move_to_element(ele[14]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 13
ac.move_to_element(ele[2]).click()
ac.pause(0.6)
ac.move_to_element(ele[15]).click()
ac.pause(0.2)

# 14
ac.move_to_element(ele[21]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.3)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 15
ac.move_to_element(ele[19]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.5)

# 16
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[14]).click()
ac.pause(0.2)
ac.move_to_element(ele[1]).click()
ac.pause(0.2)
ac.move_to_element(ele[8]).click()
ac.pause(0.2)

# 17
ac.move_to_element(ele[14]).click()
ac.pause(0.6)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[19]).click()
ac.pause(0.1)

# 18
ac.move_to_element(ele[0]).click()
ac.pause(0.3)
ac.move_to_element(ele[19]).click()
ac.pause(0.1)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)
ac.move_to_element(ele[18]).click()
ac.pause(0.2)

# 19
ac.move_to_element(ele[19]).click()
ac.pause(0.6)
ac.move_to_element(ele[2]).click()
ac.pause(0.1)
ac.move_to_element(ele[2]).click()
ac.pause(0.1)

# 20
ac.move_to_element(ele[7]).click()
ac.pause(0.3)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)

# 21
ac.move_to_element(ele[0]).click()
ac.pause(0.8)

# 22
ac.move_to_element(ele[14]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[19]).click()
ac.pause(0.2)

# 23
ac.move_to_element(ele[7]).click()
ac.pause(0.3)
ac.move_to_element(ele[2]).click()
ac.pause(0.1)
ac.move_to_element(ele[2]).click()
ac.pause(0.4)

# 24
ac.move_to_element(ele[6]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)
ac.move_to_element(ele[19]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 25
ac.move_to_element(ele[0]).click()
ac.pause(0.6)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)

# 26
ac.move_to_element(ele[30]).click()
ac.pause(0.3)
ac.move_to_element(ele[30]).click()
ac.pause(0.1)
ac.move_to_element(ele[18]).click()
ac.pause(0.3)
ac.move_to_element(ele[18]).click()
ac.pause(0.1)

# 27
ac.move_to_element(ele[0]).click()
ac.pause(0.1)
ac.move_to_element(ele[19]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.4)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 28
ac.move_to_element(ele[19]).click()
ac.pause(0.3)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[19]).click()
ac.pause(0.2)
ac.move_to_element(ele[18]).click()
ac.pause(0.2)

# 29
ac.move_to_element(ele[0]).click()
ac.pause(0.6)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)

# 30
ac.move_to_element(ele[30]).click()
ac.pause(0.3)
ac.move_to_element(ele[30]).click()
ac.pause(0.1)
ac.move_to_element(ele[18]).click()
ac.pause(0.3)
ac.move_to_element(ele[18]).click()
ac.pause(0.1)

# 31
ac.move_to_element(ele[0]).click()
ac.pause(0.1)
ac.move_to_element(ele[19]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.4)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 32
ac.move_to_element(ele[19]).click()
ac.pause(0.3)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[19]).click()
ac.pause(0.2)
ac.move_to_element(ele[1]).click()
ac.pause(0.2)

# 33
ac.move_to_element(ele[14]).click()
ac.pause(0.6)
ac.move_to_element(ele[14]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)

# 34
ac.move_to_element(ele[7]).click()
ac.pause(0.3)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.2)

# 35
ac.move_to_element(ele[1]).click()
ac.pause(0.6)
ac.move_to_element(ele[15]).click()
ac.pause(0.2)

# 36
ac.move_to_element(ele[14]).click()
ac.pause(0.3)
ac.move_to_element(ele[2]).click()
ac.pause(0.1)
ac.move_to_element(ele[14]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 37
ac.move_to_element(ele[2]).click()
ac.pause(0.6)
ac.move_to_element(ele[15]).click()
ac.pause(0.2)

# 38
ac.move_to_element(ele[21]).click()
ac.pause(0.2)
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.3)
ac.move_to_element(ele[7]).click()
ac.pause(0.2)

# 39
ac.move_to_element(ele[19]).click()
ac.pause(0.2)
ac.move_to_element(ele[0]).click()
ac.pause(0.1)
ac.move_to_element(ele[7]).click()
ac.pause(0.5)

# 40
ac.move_to_element(ele[7]).click()
ac.pause(0.1)
ac.move_to_element(ele[1]).click()
ac.pause(0.1)
ac.move_to_element(ele[14]).click()
ac.pause(0.2)
ac.move_to_element(ele[1]).click()
ac.pause(0.2)
ac.move_to_element(ele[8]).click()
ac.pause(0.2)

# 41
ac.move_to_element(ele[14]).click()
ac.pause(1.6)


ac.perform()
